# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from google.colab import drive

# path to json file that stores MFCCs and genre labels for each processed segment
drive.mount('/content/gdrive')
DATA_PATH='/content/gdrive/MyDrive/data_3.json'


def load_data(data_path):

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):


    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # add an axis to input sets
    X_train = X_train[..., np.newaxis]
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):


    # build network topology
    model = keras.Sequential()

    # 1st conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd conv layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd conv layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(4, activation='softmax'))

    return model


def predict(model, X, y):


    # add a dimension to input data for sample - model.predict() expects a 4d array in this case
    X = X[np.newaxis, ...] # array shape (1, 130, 13, 1)

    # perform prediction
    prediction = model.predict(X)

    # get index with max value
    predicted_index = np.argmax(prediction, axis=1)

    print("Target: {}, Predicted label: {}".format(y, predicted_index))


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2], 1)
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=64, epochs=100)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)

    # pick a sample to predict from the test set
    X_to_predict = X_test[100]
    y_to_predict = y_test[100]

    # predict sample
    predict(model, X_to_predict, y_to_predict)
# Out:
# Mounted at /content/gdrive
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 142, 11, 32)       320
#
#  max_pooling2d_9 (MaxPooling  (None, 71, 6, 32)        0
#  2D)
#
#  batch_normalization_9 (Batc  (None, 71, 6, 32)        128
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 69, 4, 32)         9248
#
#  max_pooling2d_10 (MaxPoolin  (None, 35, 2, 32)        0
#  g2D)
#
#  batch_normalization_10 (Bat  (None, 35, 2, 32)        128
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 34, 1, 32)         4128
#
#  max_pooling2d_11 (MaxPoolin  (None, 17, 1, 32)        0
#  g2D)
#
#  batch_normalization_11 (Bat  (None, 17, 1, 32)        128
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 544)               0
#
#  dense_6 (Dense)             (None, 64)                34880
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 49,220
# Trainable params: 49,028
# Non-trainable params: 192
# _________________________________________________________________
# Epoch 1/100
# 16/16 [==============================] - 4s 174ms/step - loss: 1.0715 - accuracy: 0.5450 - val_loss: 6.5710 - val_accuracy: 0.2590
# Epoch 2/100
# 16/16 [==============================] - 2s 150ms/step - loss: 0.6177 - accuracy: 0.7320 - val_loss: 6.5323 - val_accuracy: 0.2510
# Epoch 3/100
# 16/16 [==============================] - 2s 147ms/step - loss: 0.4608 - accuracy: 0.7980 - val_loss: 4.1483 - val_accuracy: 0.2988
# Epoch 4/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.3724 - accuracy: 0.8530 - val_loss: 3.1570 - val_accuracy: 0.3426
# Epoch 5/100
# 16/16 [==============================] - 2s 148ms/step - loss: 0.3005 - accuracy: 0.8830 - val_loss: 2.1009 - val_accuracy: 0.4502
# Epoch 6/100
# 16/16 [==============================] - 2s 147ms/step - loss: 0.2872 - accuracy: 0.8800 - val_loss: 1.4457 - val_accuracy: 0.5418
# Epoch 7/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.2513 - accuracy: 0.9030 - val_loss: 1.1339 - val_accuracy: 0.6255
# Epoch 8/100
# 16/16 [==============================] - 2s 148ms/step - loss: 0.2183 - accuracy: 0.9210 - val_loss: 0.6728 - val_accuracy: 0.7729
# Epoch 9/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.2058 - accuracy: 0.9250 - val_loss: 0.5784 - val_accuracy: 0.7888
# Epoch 10/100
# 16/16 [==============================] - 2s 147ms/step - loss: 0.1838 - accuracy: 0.9430 - val_loss: 0.5145 - val_accuracy: 0.8048
# Epoch 11/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.1354 - accuracy: 0.9540 - val_loss: 0.3828 - val_accuracy: 0.8446
# Epoch 12/100
# 16/16 [==============================] - 2s 148ms/step - loss: 0.1402 - accuracy: 0.9490 - val_loss: 0.4363 - val_accuracy: 0.8367
# Epoch 13/100
# 16/16 [==============================] - 2s 147ms/step - loss: 0.1562 - accuracy: 0.9500 - val_loss: 0.3953 - val_accuracy: 0.8406
# Epoch 14/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.1436 - accuracy: 0.9510 - val_loss: 0.3537 - val_accuracy: 0.8406
# Epoch 15/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.1251 - accuracy: 0.9600 - val_loss: 0.3239 - val_accuracy: 0.8805
# Epoch 16/100
# 16/16 [==============================] - 2s 154ms/step - loss: 0.1157 - accuracy: 0.9560 - val_loss: 0.3040 - val_accuracy: 0.8486
# Epoch 17/100
# 16/16 [==============================] - 3s 157ms/step - loss: 0.0909 - accuracy: 0.9690 - val_loss: 0.2915 - val_accuracy: 0.8884
# Epoch 18/100
# 16/16 [==============================] - 2s 153ms/step - loss: 0.0952 - accuracy: 0.9660 - val_loss: 0.3418 - val_accuracy: 0.8725
# Epoch 19/100
# 16/16 [==============================] - 2s 155ms/step - loss: 0.0965 - accuracy: 0.9670 - val_loss: 0.3487 - val_accuracy: 0.8685
# Epoch 20/100
# 16/16 [==============================] - 2s 154ms/step - loss: 0.0893 - accuracy: 0.9700 - val_loss: 0.3129 - val_accuracy: 0.8924
# Epoch 21/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0729 - accuracy: 0.9740 - val_loss: 0.2404 - val_accuracy: 0.9084
# Epoch 22/100
# 16/16 [==============================] - 2s 154ms/step - loss: 0.0580 - accuracy: 0.9800 - val_loss: 0.2451 - val_accuracy: 0.9044
# Epoch 23/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0688 - accuracy: 0.9750 - val_loss: 0.1978 - val_accuracy: 0.9084
# Epoch 24/100
# 16/16 [==============================] - 2s 148ms/step - loss: 0.0556 - accuracy: 0.9870 - val_loss: 0.2363 - val_accuracy: 0.9124
# Epoch 25/100
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0459 - accuracy: 0.9840 - val_loss: 0.3025 - val_accuracy: 0.8964
# Epoch 26/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0444 - accuracy: 0.9900 - val_loss: 0.2719 - val_accuracy: 0.9044
# Epoch 27/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0385 - accuracy: 0.9870 - val_loss: 0.2791 - val_accuracy: 0.8924
# Epoch 28/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0317 - accuracy: 0.9950 - val_loss: 0.3034 - val_accuracy: 0.9044
# Epoch 29/100
# 16/16 [==============================] - 2s 153ms/step - loss: 0.0478 - accuracy: 0.9850 - val_loss: 0.2307 - val_accuracy: 0.9004
# Epoch 30/100
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0558 - accuracy: 0.9830 - val_loss: 0.4277 - val_accuracy: 0.8566
# Epoch 31/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0720 - accuracy: 0.9750 - val_loss: 0.2967 - val_accuracy: 0.9044
# Epoch 32/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0709 - accuracy: 0.9810 - val_loss: 0.2422 - val_accuracy: 0.9004
# Epoch 33/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0641 - accuracy: 0.9780 - val_loss: 0.3262 - val_accuracy: 0.8964
# Epoch 34/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0326 - accuracy: 0.9950 - val_loss: 0.2814 - val_accuracy: 0.9124
# Epoch 35/100
# 16/16 [==============================] - 2s 153ms/step - loss: 0.0446 - accuracy: 0.9860 - val_loss: 0.2220 - val_accuracy: 0.9203
# Epoch 36/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0412 - accuracy: 0.9860 - val_loss: 0.2226 - val_accuracy: 0.9283
# Epoch 37/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0472 - accuracy: 0.9840 - val_loss: 0.4211 - val_accuracy: 0.8765
# Epoch 38/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0399 - accuracy: 0.9860 - val_loss: 0.2780 - val_accuracy: 0.9004
# Epoch 39/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0345 - accuracy: 0.9880 - val_loss: 0.2313 - val_accuracy: 0.9044
# Epoch 40/100
# 16/16 [==============================] - 2s 153ms/step - loss: 0.0243 - accuracy: 0.9920 - val_loss: 0.3354 - val_accuracy: 0.9084
# Epoch 41/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0380 - accuracy: 0.9860 - val_loss: 0.3863 - val_accuracy: 0.8924
# Epoch 42/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0302 - accuracy: 0.9900 - val_loss: 0.3893 - val_accuracy: 0.8884
# Epoch 43/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0203 - accuracy: 0.9970 - val_loss: 0.4133 - val_accuracy: 0.8964
# Epoch 44/100
# 16/16 [==============================] - 2s 148ms/step - loss: 0.0193 - accuracy: 0.9950 - val_loss: 0.3061 - val_accuracy: 0.9084
# Epoch 45/100
# 16/16 [==============================] - 2s 148ms/step - loss: 0.0150 - accuracy: 0.9950 - val_loss: 0.3360 - val_accuracy: 0.9004
# Epoch 46/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0334 - accuracy: 0.9890 - val_loss: 0.3558 - val_accuracy: 0.9084
# Epoch 47/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0438 - accuracy: 0.9840 - val_loss: 0.2714 - val_accuracy: 0.9243
# Epoch 48/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0327 - accuracy: 0.9870 - val_loss: 0.6585 - val_accuracy: 0.8725
# Epoch 49/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0561 - accuracy: 0.9790 - val_loss: 0.3914 - val_accuracy: 0.8884
# Epoch 50/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0265 - accuracy: 0.9940 - val_loss: 0.3652 - val_accuracy: 0.8924
# Epoch 51/100
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0250 - accuracy: 0.9970 - val_loss: 0.3963 - val_accuracy: 0.9084
# Epoch 52/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0312 - accuracy: 0.9910 - val_loss: 0.4723 - val_accuracy: 0.8725
# Epoch 53/100
# 16/16 [==============================] - 2s 153ms/step - loss: 0.0168 - accuracy: 0.9970 - val_loss: 0.4617 - val_accuracy: 0.9044
# Epoch 54/100
# 16/16 [==============================] - 3s 213ms/step - loss: 0.0231 - accuracy: 0.9940 - val_loss: 0.4483 - val_accuracy: 0.9044
# Epoch 55/100
# 16/16 [==============================] - 3s 215ms/step - loss: 0.0196 - accuracy: 0.9960 - val_loss: 0.6977 - val_accuracy: 0.8526
# Epoch 56/100
# 16/16 [==============================] - 2s 148ms/step - loss: 0.0169 - accuracy: 0.9980 - val_loss: 0.2356 - val_accuracy: 0.9363
# Epoch 57/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0145 - accuracy: 0.9950 - val_loss: 0.2715 - val_accuracy: 0.9283
# Epoch 58/100
# 16/16 [==============================] - 2s 154ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.4248 - val_accuracy: 0.8924
# Epoch 59/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0127 - accuracy: 0.9970 - val_loss: 0.3693 - val_accuracy: 0.9163
# Epoch 60/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0148 - accuracy: 0.9970 - val_loss: 0.3587 - val_accuracy: 0.8924
# Epoch 61/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0186 - accuracy: 0.9950 - val_loss: 0.3847 - val_accuracy: 0.8924
# Epoch 62/100
# 16/16 [==============================] - 2s 147ms/step - loss: 0.0121 - accuracy: 0.9980 - val_loss: 0.2892 - val_accuracy: 0.9084
# Epoch 63/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0134 - accuracy: 0.9970 - val_loss: 0.2460 - val_accuracy: 0.9323
# Epoch 64/100
# 16/16 [==============================] - 2s 153ms/step - loss: 0.0166 - accuracy: 0.9940 - val_loss: 0.5296 - val_accuracy: 0.8765
# Epoch 65/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0252 - accuracy: 0.9930 - val_loss: 0.2841 - val_accuracy: 0.9283
# Epoch 66/100
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0115 - accuracy: 0.9970 - val_loss: 0.2895 - val_accuracy: 0.9323
# Epoch 67/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0077 - accuracy: 0.9970 - val_loss: 0.3176 - val_accuracy: 0.9203
# Epoch 68/100
# 16/16 [==============================] - 2s 153ms/step - loss: 0.0067 - accuracy: 0.9990 - val_loss: 0.3663 - val_accuracy: 0.9203
# Epoch 69/100
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.3614 - val_accuracy: 0.9163
# Epoch 70/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0108 - accuracy: 0.9960 - val_loss: 0.3076 - val_accuracy: 0.9124
# Epoch 71/100
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0113 - accuracy: 0.9970 - val_loss: 0.3935 - val_accuracy: 0.9004
# Epoch 72/100
# 16/16 [==============================] - 2s 153ms/step - loss: 0.0154 - accuracy: 0.9960 - val_loss: 0.3498 - val_accuracy: 0.9163
# Epoch 73/100
# 16/16 [==============================] - 2s 154ms/step - loss: 0.0219 - accuracy: 0.9940 - val_loss: 0.3184 - val_accuracy: 0.9124
# Epoch 74/100
# 16/16 [==============================] - 2s 156ms/step - loss: 0.0292 - accuracy: 0.9880 - val_loss: 0.4297 - val_accuracy: 0.9163
# Epoch 75/100
# 16/16 [==============================] - 3s 222ms/step - loss: 0.0145 - accuracy: 0.9960 - val_loss: 0.3659 - val_accuracy: 0.8884
# Epoch 76/100
# 16/16 [==============================] - 3s 209ms/step - loss: 0.0124 - accuracy: 0.9980 - val_loss: 0.3478 - val_accuracy: 0.9044
# Epoch 77/100
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0114 - accuracy: 0.9990 - val_loss: 0.3344 - val_accuracy: 0.9004
# Epoch 78/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0075 - accuracy: 0.9970 - val_loss: 0.2889 - val_accuracy: 0.9283
# Epoch 79/100
# 16/16 [==============================] - 2s 147ms/step - loss: 0.0131 - accuracy: 0.9960 - val_loss: 0.2848 - val_accuracy: 0.9283
# Epoch 80/100
# 16/16 [==============================] - 2s 148ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.2793 - val_accuracy: 0.9203
# Epoch 81/100
# 16/16 [==============================] - 2s 148ms/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 0.2612 - val_accuracy: 0.9283
# Epoch 82/100
# 16/16 [==============================] - 2s 147ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9323
# Epoch 83/100
# 16/16 [==============================] - 2s 146ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.2873 - val_accuracy: 0.9323
# Epoch 84/100
# 16/16 [==============================] - 2s 145ms/step - loss: 0.0140 - accuracy: 0.9950 - val_loss: 0.2859 - val_accuracy: 0.9283
# Epoch 85/100
# 16/16 [==============================] - 2s 146ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2950 - val_accuracy: 0.9203
# Epoch 86/100
# 16/16 [==============================] - 2s 148ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.3524 - val_accuracy: 0.9243
# Epoch 87/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 0.3614 - val_accuracy: 0.9163
# Epoch 88/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0092 - accuracy: 0.9960 - val_loss: 0.3085 - val_accuracy: 0.9124
# Epoch 89/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3996 - val_accuracy: 0.9243
# Epoch 90/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0067 - accuracy: 0.9970 - val_loss: 0.6292 - val_accuracy: 0.8645
# Epoch 91/100
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0068 - accuracy: 0.9970 - val_loss: 0.3145 - val_accuracy: 0.9243
# Epoch 92/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3144 - val_accuracy: 0.9363
# Epoch 93/100
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3463 - val_accuracy: 0.9243
# Epoch 94/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.3286 - val_accuracy: 0.9203
# Epoch 95/100
# 16/16 [==============================] - 2s 153ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2787 - val_accuracy: 0.9402
# Epoch 96/100
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2803 - val_accuracy: 0.9363
# Epoch 97/100
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2639 - val_accuracy: 0.9363
# Epoch 98/100
# 16/16 [==============================] - 2s 153ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.2911 - val_accuracy: 0.9243
# Epoch 99/100
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3184 - val_accuracy: 0.9203
# Epoch 100/100
# 16/16 [==============================] - 2s 148ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.3627 - val_accuracy: 0.9044
# 14/14 - 0s - loss: 0.2241 - accuracy: 0.9400 - 245ms/epoch - 17ms/step
#
# Test accuracy: 0.9400479793548584
# 1/1 [==============================] - 0s 129ms/step
# Target: 1, Predicted label: [1]

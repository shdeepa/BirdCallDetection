# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from google.colab import drive

# path to json file that stores MFCCs and genre labels for each processed segment
drive.mount('/content/gdrive')
DATA_PATH='/content/gdrive/MyDrive/data_3.json'


def load_data(data_path):
  
    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()


def prepare_datasets(test_size, validation_size):
   
    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
  
    # build network topology
    model = keras.Sequential()

    # 2 LSTM layers
    model.add(keras.layers.LSTM(64, input_shape=input_shape, return_sequences=True))
    model.add(keras.layers.LSTM(64))

    # dense layer
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(4, activation='softmax'))

    return model


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2]) # 130, 13
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=64, epochs=100)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 144, 64)           19968
#
#  lstm_5 (LSTM)               (None, 64)                33024
#
#  dense_16 (Dense)            (None, 64)                4160
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_17 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 57,412
# Trainable params: 57,412
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 16/16 [==============================] - 7s 240ms/step - loss: 1.1878 - accuracy: 0.4720 - val_loss: 0.9581 - val_accuracy: 0.5618
# Epoch 2/100
# 16/16 [==============================] - 3s 191ms/step - loss: 0.8481 - accuracy: 0.6320 - val_loss: 0.6774 - val_accuracy: 0.6972
# Epoch 3/100
# 16/16 [==============================] - 3s 210ms/step - loss: 0.6425 - accuracy: 0.6850 - val_loss: 0.6304 - val_accuracy: 0.6932
# Epoch 4/100
# 16/16 [==============================] - 3s 188ms/step - loss: 0.5524 - accuracy: 0.7330 - val_loss: 0.6151 - val_accuracy: 0.6773
# Epoch 5/100
# 16/16 [==============================] - 3s 186ms/step - loss: 0.5251 - accuracy: 0.7440 - val_loss: 0.5462 - val_accuracy: 0.7729
# Epoch 6/100
# 16/16 [==============================] - 3s 194ms/step - loss: 0.4798 - accuracy: 0.7790 - val_loss: 0.5335 - val_accuracy: 0.7809
# Epoch 7/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.4147 - accuracy: 0.8310 - val_loss: 0.5498 - val_accuracy: 0.7729
# Epoch 8/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.4586 - accuracy: 0.8190 - val_loss: 0.5333 - val_accuracy: 0.8207
# Epoch 9/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.4484 - accuracy: 0.8210 - val_loss: 0.5240 - val_accuracy: 0.7849
# Epoch 10/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.3634 - accuracy: 0.8470 - val_loss: 0.4566 - val_accuracy: 0.8167
# Epoch 11/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.3014 - accuracy: 0.8760 - val_loss: 0.5066 - val_accuracy: 0.8127
# Epoch 12/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.2592 - accuracy: 0.9050 - val_loss: 0.4519 - val_accuracy: 0.8327
# Epoch 13/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.2592 - accuracy: 0.8970 - val_loss: 0.5575 - val_accuracy: 0.7928
# Epoch 14/100
# 16/16 [==============================] - 3s 205ms/step - loss: 0.2697 - accuracy: 0.8950 - val_loss: 0.4861 - val_accuracy: 0.8287
# Epoch 15/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.2338 - accuracy: 0.9150 - val_loss: 0.5082 - val_accuracy: 0.8406
# Epoch 16/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.2579 - accuracy: 0.9030 - val_loss: 0.6044 - val_accuracy: 0.7729
# Epoch 17/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.2325 - accuracy: 0.9060 - val_loss: 0.4823 - val_accuracy: 0.8327
# Epoch 18/100
# 16/16 [==============================] - 3s 201ms/step - loss: 0.1762 - accuracy: 0.9380 - val_loss: 0.4380 - val_accuracy: 0.8566
# Epoch 19/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.1461 - accuracy: 0.9480 - val_loss: 0.4941 - val_accuracy: 0.8287
# Epoch 20/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.1396 - accuracy: 0.9490 - val_loss: 0.4112 - val_accuracy: 0.8725
# Epoch 21/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.1202 - accuracy: 0.9570 - val_loss: 0.5828 - val_accuracy: 0.8526
# Epoch 22/100
# 16/16 [==============================] - 3s 205ms/step - loss: 0.1211 - accuracy: 0.9640 - val_loss: 0.4976 - val_accuracy: 0.8566
# Epoch 23/100
# 16/16 [==============================] - 3s 205ms/step - loss: 0.1322 - accuracy: 0.9560 - val_loss: 0.4585 - val_accuracy: 0.8606
# Epoch 24/100
# 16/16 [==============================] - 3s 201ms/step - loss: 0.2661 - accuracy: 0.9070 - val_loss: 0.5818 - val_accuracy: 0.8008
# Epoch 25/100
# 16/16 [==============================] - 3s 200ms/step - loss: 0.2691 - accuracy: 0.8980 - val_loss: 0.4863 - val_accuracy: 0.8167
# Epoch 26/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.2153 - accuracy: 0.9240 - val_loss: 0.4141 - val_accuracy: 0.8446
# Epoch 27/100
# 16/16 [==============================] - 3s 205ms/step - loss: 0.1567 - accuracy: 0.9420 - val_loss: 0.4660 - val_accuracy: 0.8486
# Epoch 28/100
# 16/16 [==============================] - 3s 203ms/step - loss: 0.1074 - accuracy: 0.9660 - val_loss: 0.4918 - val_accuracy: 0.8446
# Epoch 29/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.1076 - accuracy: 0.9610 - val_loss: 0.5830 - val_accuracy: 0.8367
# Epoch 30/100
# 16/16 [==============================] - 3s 205ms/step - loss: 0.1291 - accuracy: 0.9550 - val_loss: 0.4948 - val_accuracy: 0.8446
# Epoch 31/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.1153 - accuracy: 0.9630 - val_loss: 0.5122 - val_accuracy: 0.8406
# Epoch 32/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.0847 - accuracy: 0.9740 - val_loss: 0.5967 - val_accuracy: 0.8406
# Epoch 33/100
# 16/16 [==============================] - 3s 205ms/step - loss: 0.0705 - accuracy: 0.9770 - val_loss: 0.6280 - val_accuracy: 0.8486
# Epoch 34/100
# 16/16 [==============================] - 3s 201ms/step - loss: 0.1133 - accuracy: 0.9660 - val_loss: 0.5610 - val_accuracy: 0.8526
# Epoch 35/100
# 16/16 [==============================] - 3s 199ms/step - loss: 0.0850 - accuracy: 0.9720 - val_loss: 0.6067 - val_accuracy: 0.8486
# Epoch 36/100
# 16/16 [==============================] - 3s 200ms/step - loss: 0.0598 - accuracy: 0.9800 - val_loss: 0.6188 - val_accuracy: 0.8486
# Epoch 37/100
# 16/16 [==============================] - 3s 203ms/step - loss: 0.0724 - accuracy: 0.9770 - val_loss: 0.5217 - val_accuracy: 0.8566
# Epoch 38/100
# 16/16 [==============================] - 3s 203ms/step - loss: 0.0679 - accuracy: 0.9730 - val_loss: 0.4649 - val_accuracy: 0.8645
# Epoch 39/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.0610 - accuracy: 0.9840 - val_loss: 0.5362 - val_accuracy: 0.8685
# Epoch 40/100
# 16/16 [==============================] - 3s 203ms/step - loss: 0.1201 - accuracy: 0.9660 - val_loss: 0.5345 - val_accuracy: 0.8526
# Epoch 41/100
# 16/16 [==============================] - 5s 293ms/step - loss: 0.0875 - accuracy: 0.9660 - val_loss: 0.4894 - val_accuracy: 0.8685
# Epoch 42/100
# 16/16 [==============================] - 4s 216ms/step - loss: 0.0744 - accuracy: 0.9780 - val_loss: 0.4967 - val_accuracy: 0.8685
# Epoch 43/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.0540 - accuracy: 0.9830 - val_loss: 0.4789 - val_accuracy: 0.8765
# Epoch 44/100
# 16/16 [==============================] - 3s 199ms/step - loss: 0.0383 - accuracy: 0.9910 - val_loss: 0.4554 - val_accuracy: 0.8964
# Epoch 45/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.0417 - accuracy: 0.9880 - val_loss: 0.5445 - val_accuracy: 0.8805
# Epoch 46/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0587 - accuracy: 0.9780 - val_loss: 0.6142 - val_accuracy: 0.8725
# Epoch 47/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.0867 - accuracy: 0.9690 - val_loss: 0.6592 - val_accuracy: 0.8247
# Epoch 48/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0747 - accuracy: 0.9770 - val_loss: 0.5653 - val_accuracy: 0.8606
# Epoch 49/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.0504 - accuracy: 0.9840 - val_loss: 0.6100 - val_accuracy: 0.8685
# Epoch 50/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.0388 - accuracy: 0.9890 - val_loss: 0.6278 - val_accuracy: 0.8645
# Epoch 51/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0354 - accuracy: 0.9910 - val_loss: 0.6705 - val_accuracy: 0.8645
# Epoch 52/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0759 - accuracy: 0.9790 - val_loss: 0.7101 - val_accuracy: 0.8446
# Epoch 53/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.1326 - accuracy: 0.9510 - val_loss: 0.6398 - val_accuracy: 0.8446
# Epoch 54/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0909 - accuracy: 0.9680 - val_loss: 0.5590 - val_accuracy: 0.8526
# Epoch 55/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.1128 - accuracy: 0.9610 - val_loss: 0.5313 - val_accuracy: 0.8486
# Epoch 56/100
# 16/16 [==============================] - 3s 205ms/step - loss: 0.0593 - accuracy: 0.9840 - val_loss: 0.5844 - val_accuracy: 0.8446
# Epoch 57/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.0268 - accuracy: 0.9940 - val_loss: 0.6171 - val_accuracy: 0.8526
# Epoch 58/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0178 - accuracy: 0.9970 - val_loss: 0.6524 - val_accuracy: 0.8725
# Epoch 59/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.0196 - accuracy: 0.9940 - val_loss: 0.6674 - val_accuracy: 0.8725
# Epoch 60/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0333 - accuracy: 0.9870 - val_loss: 0.6337 - val_accuracy: 0.8606
# Epoch 61/100
# 16/16 [==============================] - 3s 203ms/step - loss: 0.0393 - accuracy: 0.9850 - val_loss: 0.6823 - val_accuracy: 0.8406
# Epoch 62/100
# 16/16 [==============================] - 3s 208ms/step - loss: 0.0422 - accuracy: 0.9890 - val_loss: 0.7130 - val_accuracy: 0.8446
# Epoch 63/100
# 16/16 [==============================] - 3s 203ms/step - loss: 0.0236 - accuracy: 0.9920 - val_loss: 0.7322 - val_accuracy: 0.8367
# Epoch 64/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.0304 - accuracy: 0.9910 - val_loss: 0.7036 - val_accuracy: 0.8566
# Epoch 65/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.0898 - accuracy: 0.9820 - val_loss: 0.6603 - val_accuracy: 0.8685
# Epoch 66/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0580 - accuracy: 0.9830 - val_loss: 0.6206 - val_accuracy: 0.8805
# Epoch 67/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.0836 - accuracy: 0.9710 - val_loss: 0.6912 - val_accuracy: 0.8685
# Epoch 68/100
# 16/16 [==============================] - 3s 209ms/step - loss: 0.0997 - accuracy: 0.9680 - val_loss: 0.5552 - val_accuracy: 0.8685
# Epoch 69/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.0451 - accuracy: 0.9890 - val_loss: 0.5443 - val_accuracy: 0.8805
# Epoch 70/100
# 16/16 [==============================] - 3s 205ms/step - loss: 0.0446 - accuracy: 0.9860 - val_loss: 0.6189 - val_accuracy: 0.8645
# Epoch 71/100
# 16/16 [==============================] - 3s 205ms/step - loss: 0.0412 - accuracy: 0.9880 - val_loss: 0.6426 - val_accuracy: 0.8845
# Epoch 72/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0262 - accuracy: 0.9920 - val_loss: 0.5984 - val_accuracy: 0.8765
# Epoch 73/100
# 16/16 [==============================] - 3s 203ms/step - loss: 0.0236 - accuracy: 0.9940 - val_loss: 0.6952 - val_accuracy: 0.8685
# Epoch 74/100
# 16/16 [==============================] - 3s 199ms/step - loss: 0.0270 - accuracy: 0.9880 - val_loss: 0.7817 - val_accuracy: 0.8606
# Epoch 75/100
# 16/16 [==============================] - 3s 207ms/step - loss: 0.0540 - accuracy: 0.9790 - val_loss: 0.6812 - val_accuracy: 0.8606
# Epoch 76/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.0632 - accuracy: 0.9830 - val_loss: 0.6287 - val_accuracy: 0.8645
# Epoch 77/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.0498 - accuracy: 0.9870 - val_loss: 0.5575 - val_accuracy: 0.9004
# Epoch 78/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.0505 - accuracy: 0.9880 - val_loss: 0.6895 - val_accuracy: 0.8765
# Epoch 79/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.0683 - accuracy: 0.9800 - val_loss: 0.6025 - val_accuracy: 0.8526
# Epoch 80/100
# 16/16 [==============================] - 3s 206ms/step - loss: 0.0411 - accuracy: 0.9860 - val_loss: 0.5100 - val_accuracy: 0.8725
# Epoch 81/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.0405 - accuracy: 0.9870 - val_loss: 0.5416 - val_accuracy: 0.8805
# Epoch 82/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.0595 - accuracy: 0.9810 - val_loss: 0.5611 - val_accuracy: 0.8725
# Epoch 83/100
# 16/16 [==============================] - 3s 201ms/step - loss: 0.0704 - accuracy: 0.9820 - val_loss: 0.7035 - val_accuracy: 0.8446
# Epoch 84/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.0420 - accuracy: 0.9850 - val_loss: 0.5523 - val_accuracy: 0.8765
# Epoch 85/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.0382 - accuracy: 0.9890 - val_loss: 0.4983 - val_accuracy: 0.8805
# Epoch 86/100
# 16/16 [==============================] - 3s 198ms/step - loss: 0.0192 - accuracy: 0.9970 - val_loss: 0.5981 - val_accuracy: 0.8685
# Epoch 87/100
# 16/16 [==============================] - 3s 198ms/step - loss: 0.0099 - accuracy: 0.9980 - val_loss: 0.6164 - val_accuracy: 0.8685
# Epoch 88/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 0.6300 - val_accuracy: 0.8805
# Epoch 89/100
# 16/16 [==============================] - 3s 201ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.6389 - val_accuracy: 0.8845
# Epoch 90/100
# 16/16 [==============================] - 3s 199ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.6662 - val_accuracy: 0.8805
# Epoch 91/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.7093 - val_accuracy: 0.8805
# Epoch 92/100
# 16/16 [==============================] - 3s 202ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.7344 - val_accuracy: 0.8765
# Epoch 93/100
# 16/16 [==============================] - 3s 204ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.7379 - val_accuracy: 0.8805
# Epoch 94/100
# 16/16 [==============================] - 5s 304ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7645 - val_accuracy: 0.8765
# Epoch 95/100
# 16/16 [==============================] - 3s 209ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7952 - val_accuracy: 0.8725
# Epoch 96/100
# 16/16 [==============================] - 3s 205ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8044 - val_accuracy: 0.8765
# Epoch 97/100
# 16/16 [==============================] - 3s 205ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8289 - val_accuracy: 0.8765
# Epoch 98/100
# 16/16 [==============================] - 3s 207ms/step - loss: 9.5556e-04 - accuracy: 1.0000 - val_loss: 0.8266 - val_accuracy: 0.8765
# Epoch 99/100
# 16/16 [==============================] - 3s 203ms/step - loss: 8.9182e-04 - accuracy: 1.0000 - val_loss: 0.8396 - val_accuracy: 0.8765
# Epoch 100/100
# 16/16 [==============================] - 3s 201ms/step - loss: 9.8568e-04 - accuracy: 1.0000 - val_loss: 0.8562 - val_accuracy: 0.8725
# 14/14 - 1s - loss: 0.4865 - accuracy: 0.9185 - 502ms/epoch - 36ms/step
#
# Test accuracy: 0.918465256690979

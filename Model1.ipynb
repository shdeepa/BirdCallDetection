# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from google.colab import drive

# path to json file that stores MFCCs and genre labels for each processed segment
drive.mount('/content/gdrive')
DATA_PATH='/content/gdrive/MyDrive/data_3.json'


def load_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y

def plot_history(history):

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

if __name__ == "__main__":

    # load data
    X, y = load_data(DATA_PATH)

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

    # build network topology
    model = keras.Sequential([

        # input layer
        keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),

        # 1st dense layer
        keras.layers.Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        # 2nd dense layer
        keras.layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        # 3rd dense layer
        keras.layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
        keras.layers.Dropout(0.3),

        # output layer
        keras.layers.Dense(4, activation='softmax')
    ])

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])


    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=64, epochs=100)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Data succesfully loaded!
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 1872)              0
#
#  dense_8 (Dense)             (None, 512)               958976
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_9 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 64)                16448
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 1,107,012
# Trainable params: 1,107,012
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 19/19 [==============================] - 1s 22ms/step - loss: 57.7961 - accuracy: 0.4096 - val_loss: 5.7563 - val_accuracy: 0.6188
# Epoch 2/100
# 19/19 [==============================] - 0s 15ms/step - loss: 15.3265 - accuracy: 0.5733 - val_loss: 2.8695 - val_accuracy: 0.6527
# Epoch 3/100
# 19/19 [==============================] - 0s 14ms/step - loss: 7.1101 - accuracy: 0.5707 - val_loss: 2.0284 - val_accuracy: 0.4890
# Epoch 4/100
# 19/19 [==============================] - 0s 15ms/step - loss: 4.1516 - accuracy: 0.5604 - val_loss: 1.8806 - val_accuracy: 0.5868
# Epoch 5/100
# 19/19 [==============================] - 0s 16ms/step - loss: 3.0732 - accuracy: 0.5596 - val_loss: 1.8043 - val_accuracy: 0.6407
# Epoch 6/100
# 19/19 [==============================] - 0s 16ms/step - loss: 2.5081 - accuracy: 0.5767 - val_loss: 1.8649 - val_accuracy: 0.5429
# Epoch 7/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.3850 - accuracy: 0.5707 - val_loss: 1.7919 - val_accuracy: 0.6986
# Epoch 8/100
# 19/19 [==============================] - 0s 16ms/step - loss: 2.1742 - accuracy: 0.5775 - val_loss: 1.7617 - val_accuracy: 0.6267
# Epoch 9/100
# 19/19 [==============================] - 0s 14ms/step - loss: 2.2477 - accuracy: 0.5733 - val_loss: 1.7491 - val_accuracy: 0.5808
# Epoch 10/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.0739 - accuracy: 0.5613 - val_loss: 1.7554 - val_accuracy: 0.5988
# Epoch 11/100
# 19/19 [==============================] - 0s 18ms/step - loss: 2.0134 - accuracy: 0.6033 - val_loss: 1.6671 - val_accuracy: 0.7106
# Epoch 12/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.8581 - accuracy: 0.5921 - val_loss: 1.6938 - val_accuracy: 0.6587
# Epoch 13/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.8919 - accuracy: 0.5913 - val_loss: 1.6474 - val_accuracy: 0.7086
# Epoch 14/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.8604 - accuracy: 0.6213 - val_loss: 1.6388 - val_accuracy: 0.7345
# Epoch 15/100
# 19/19 [==============================] - 0s 16ms/step - loss: 1.8008 - accuracy: 0.6221 - val_loss: 1.6109 - val_accuracy: 0.7126
# Epoch 16/100
# 19/19 [==============================] - 0s 15ms/step - loss: 1.8315 - accuracy: 0.6101 - val_loss: 1.5907 - val_accuracy: 0.7206
# Epoch 17/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.8419 - accuracy: 0.6213 - val_loss: 1.5784 - val_accuracy: 0.7206
# Epoch 18/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.7710 - accuracy: 0.6427 - val_loss: 1.5706 - val_accuracy: 0.7445
# Epoch 19/100
# 19/19 [==============================] - 0s 16ms/step - loss: 1.7535 - accuracy: 0.6538 - val_loss: 1.5700 - val_accuracy: 0.7365
# Epoch 20/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.7723 - accuracy: 0.6230 - val_loss: 1.6001 - val_accuracy: 0.6806
# Epoch 21/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.7458 - accuracy: 0.6452 - val_loss: 1.5493 - val_accuracy: 0.7186
# Epoch 22/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.6869 - accuracy: 0.6332 - val_loss: 1.5436 - val_accuracy: 0.7345
# Epoch 23/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.6732 - accuracy: 0.6487 - val_loss: 1.5375 - val_accuracy: 0.7106
# Epoch 24/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.6467 - accuracy: 0.6581 - val_loss: 1.5125 - val_accuracy: 0.7325
# Epoch 25/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.6210 - accuracy: 0.6504 - val_loss: 1.5216 - val_accuracy: 0.6766
# Epoch 26/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.6477 - accuracy: 0.6530 - val_loss: 1.5193 - val_accuracy: 0.7285
# Epoch 27/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.6629 - accuracy: 0.6375 - val_loss: 1.5212 - val_accuracy: 0.7345
# Epoch 28/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.6565 - accuracy: 0.6658 - val_loss: 1.4974 - val_accuracy: 0.7006
# Epoch 29/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.6296 - accuracy: 0.6281 - val_loss: 1.4970 - val_accuracy: 0.7206
# Epoch 30/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.6440 - accuracy: 0.6418 - val_loss: 1.5032 - val_accuracy: 0.7246
# Epoch 31/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.6683 - accuracy: 0.6555 - val_loss: 1.4791 - val_accuracy: 0.7405
# Epoch 32/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.5887 - accuracy: 0.6787 - val_loss: 1.4970 - val_accuracy: 0.6906
# Epoch 33/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.5810 - accuracy: 0.6718 - val_loss: 1.4561 - val_accuracy: 0.7505
# Epoch 34/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.6220 - accuracy: 0.6941 - val_loss: 1.4728 - val_accuracy: 0.6966
# Epoch 35/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.5782 - accuracy: 0.6710 - val_loss: 1.4390 - val_accuracy: 0.7465
# Epoch 36/100
# 19/19 [==============================] - 0s 20ms/step - loss: 1.5504 - accuracy: 0.6812 - val_loss: 1.4180 - val_accuracy: 0.7585
# Epoch 37/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.5722 - accuracy: 0.6907 - val_loss: 1.4367 - val_accuracy: 0.7545
# Epoch 38/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.5819 - accuracy: 0.6855 - val_loss: 1.4299 - val_accuracy: 0.7425
# Epoch 39/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.5219 - accuracy: 0.6924 - val_loss: 1.4082 - val_accuracy: 0.7405
# Epoch 40/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.4887 - accuracy: 0.7001 - val_loss: 1.4021 - val_accuracy: 0.7525
# Epoch 41/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.4923 - accuracy: 0.6778 - val_loss: 1.3971 - val_accuracy: 0.7365
# Epoch 42/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.5242 - accuracy: 0.6812 - val_loss: 1.3948 - val_accuracy: 0.6966
# Epoch 43/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.4874 - accuracy: 0.6984 - val_loss: 1.3826 - val_accuracy: 0.7365
# Epoch 44/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.4790 - accuracy: 0.6812 - val_loss: 1.3863 - val_accuracy: 0.6866
# Epoch 45/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.4874 - accuracy: 0.6949 - val_loss: 1.3930 - val_accuracy: 0.6806
# Epoch 46/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.4441 - accuracy: 0.7078 - val_loss: 1.3572 - val_accuracy: 0.7405
# Epoch 47/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.4362 - accuracy: 0.7249 - val_loss: 1.3437 - val_accuracy: 0.7764
# Epoch 48/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.4744 - accuracy: 0.6941 - val_loss: 1.3501 - val_accuracy: 0.7265
# Epoch 49/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.4606 - accuracy: 0.6924 - val_loss: 1.3739 - val_accuracy: 0.7305
# Epoch 50/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.4331 - accuracy: 0.7044 - val_loss: 1.3317 - val_accuracy: 0.7226
# Epoch 51/100
# 19/19 [==============================] - 0s 19ms/step - loss: 1.4171 - accuracy: 0.7069 - val_loss: 1.3336 - val_accuracy: 0.7585
# Epoch 52/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.5067 - accuracy: 0.7035 - val_loss: 1.3595 - val_accuracy: 0.7066
# Epoch 53/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.4462 - accuracy: 0.7129 - val_loss: 1.3524 - val_accuracy: 0.7066
# Epoch 54/100
# 19/19 [==============================] - 0s 19ms/step - loss: 1.4771 - accuracy: 0.6992 - val_loss: 1.3214 - val_accuracy: 0.7265
# Epoch 55/100
# 19/19 [==============================] - 0s 19ms/step - loss: 1.4814 - accuracy: 0.6847 - val_loss: 1.3413 - val_accuracy: 0.7305
# Epoch 56/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.3975 - accuracy: 0.7155 - val_loss: 1.3199 - val_accuracy: 0.7385
# Epoch 57/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.4148 - accuracy: 0.6898 - val_loss: 1.3117 - val_accuracy: 0.7265
# Epoch 58/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.4002 - accuracy: 0.6992 - val_loss: 1.3022 - val_accuracy: 0.7405
# Epoch 59/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.4142 - accuracy: 0.7155 - val_loss: 1.2999 - val_accuracy: 0.7345
# Epoch 60/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.3883 - accuracy: 0.7155 - val_loss: 1.3082 - val_accuracy: 0.6966
# Epoch 61/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.3444 - accuracy: 0.7318 - val_loss: 1.2814 - val_accuracy: 0.7565
# Epoch 62/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.3797 - accuracy: 0.7009 - val_loss: 1.2683 - val_accuracy: 0.7545
# Epoch 63/100
# 19/19 [==============================] - 0s 19ms/step - loss: 1.3511 - accuracy: 0.7275 - val_loss: 1.2682 - val_accuracy: 0.7445
# Epoch 64/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.3326 - accuracy: 0.7138 - val_loss: 1.2607 - val_accuracy: 0.7565
# Epoch 65/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.3470 - accuracy: 0.7181 - val_loss: 1.2489 - val_accuracy: 0.7465
# Epoch 66/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.3086 - accuracy: 0.7326 - val_loss: 1.2448 - val_accuracy: 0.7465
# Epoch 67/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2979 - accuracy: 0.7352 - val_loss: 1.2328 - val_accuracy: 0.7545
# Epoch 68/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.3267 - accuracy: 0.7421 - val_loss: 1.2265 - val_accuracy: 0.7625
# Epoch 69/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2897 - accuracy: 0.7455 - val_loss: 1.2248 - val_accuracy: 0.7525
# Epoch 70/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.3247 - accuracy: 0.7258 - val_loss: 1.2183 - val_accuracy: 0.7605
# Epoch 71/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2946 - accuracy: 0.7506 - val_loss: 1.2271 - val_accuracy: 0.7465
# Epoch 72/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2969 - accuracy: 0.7438 - val_loss: 1.2232 - val_accuracy: 0.7465
# Epoch 73/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.2840 - accuracy: 0.7472 - val_loss: 1.2253 - val_accuracy: 0.7585
# Epoch 74/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.3049 - accuracy: 0.7344 - val_loss: 1.2049 - val_accuracy: 0.7605
# Epoch 75/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2988 - accuracy: 0.7352 - val_loss: 1.2231 - val_accuracy: 0.7525
# Epoch 76/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2748 - accuracy: 0.7429 - val_loss: 1.2006 - val_accuracy: 0.7545
# Epoch 77/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.2886 - accuracy: 0.7378 - val_loss: 1.1956 - val_accuracy: 0.7385
# Epoch 78/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2289 - accuracy: 0.7601 - val_loss: 1.2195 - val_accuracy: 0.7146
# Epoch 79/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.2499 - accuracy: 0.7421 - val_loss: 1.1854 - val_accuracy: 0.7625
# Epoch 80/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2479 - accuracy: 0.7498 - val_loss: 1.1758 - val_accuracy: 0.7625
# Epoch 81/100
# 19/19 [==============================] - 0s 19ms/step - loss: 1.2533 - accuracy: 0.7446 - val_loss: 1.2040 - val_accuracy: 0.7226
# Epoch 82/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2519 - accuracy: 0.7421 - val_loss: 1.1897 - val_accuracy: 0.7565
# Epoch 83/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2738 - accuracy: 0.7438 - val_loss: 1.1841 - val_accuracy: 0.7824
# Epoch 84/100
# 19/19 [==============================] - 0s 19ms/step - loss: 1.2343 - accuracy: 0.7489 - val_loss: 1.1947 - val_accuracy: 0.7565
# Epoch 85/100
# 19/19 [==============================] - 0s 20ms/step - loss: 1.2483 - accuracy: 0.7438 - val_loss: 1.1702 - val_accuracy: 0.7585
# Epoch 86/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.1888 - accuracy: 0.7635 - val_loss: 1.1487 - val_accuracy: 0.7645
# Epoch 87/100
# 19/19 [==============================] - 0s 19ms/step - loss: 1.1672 - accuracy: 0.7644 - val_loss: 1.1954 - val_accuracy: 0.7445
# Epoch 88/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.1571 - accuracy: 0.7644 - val_loss: 1.1563 - val_accuracy: 0.7764
# Epoch 89/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.1819 - accuracy: 0.7626 - val_loss: 1.1498 - val_accuracy: 0.7725
# Epoch 90/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.2155 - accuracy: 0.7455 - val_loss: 1.1363 - val_accuracy: 0.7585
# Epoch 91/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.1714 - accuracy: 0.7661 - val_loss: 1.1319 - val_accuracy: 0.7824
# Epoch 92/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2033 - accuracy: 0.7618 - val_loss: 1.1993 - val_accuracy: 0.7904
# Epoch 93/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.1728 - accuracy: 0.7549 - val_loss: 1.1531 - val_accuracy: 0.7705
# Epoch 94/100
# 19/19 [==============================] - 0s 19ms/step - loss: 1.2482 - accuracy: 0.7361 - val_loss: 1.1426 - val_accuracy: 0.7804
# Epoch 95/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.1832 - accuracy: 0.7584 - val_loss: 1.1278 - val_accuracy: 0.7645
# Epoch 96/100
# 19/19 [==============================] - 0s 18ms/step - loss: 1.1714 - accuracy: 0.7618 - val_loss: 1.1523 - val_accuracy: 0.7784
# Epoch 97/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.2026 - accuracy: 0.7232 - val_loss: 1.1336 - val_accuracy: 0.7685
# Epoch 98/100
# 19/19 [==============================] - 0s 16ms/step - loss: 1.1512 - accuracy: 0.7626 - val_loss: 1.1203 - val_accuracy: 0.7585
# Epoch 99/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.1283 - accuracy: 0.7952 - val_loss: 1.1309 - val_accuracy: 0.7764
# Epoch 100/100
# 19/19 [==============================] - 0s 17ms/step - loss: 1.1218 - accuracy: 0.7704 - val_loss: 1.1193 - val_accuracy: 0.7725
# 16/16 - 0s - loss: 1.1193 - accuracy: 0.7725 - 68ms/epoch - 4ms/step
#
# Test accuracy: 0.772455096244812
